# %% [markdown]
# # Question 1 - Display Header tag From Wikipedia

# %%
# !pip install bs4
# !pip install requests
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
from bs4 import BeautifulSoup
import requests

# %%
page=requests.get('https://en.wikipedia.org/wiki/Main_Page') # Calling the URl from which we have to scrap the data 
page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content) #Applying Soup function

# %%
titles=soup.find_all(['h1','h2','h3','h4','h5','h6'])    # applying soup function to extract the data 
print('List all the header tags :',*titles,sep='\n\n')
# Out:
# List all the header tags :
#
# <h1 class="firstHeading mw-first-heading" id="firstHeading" style="display: none"><span class="mw-page-title-main">Main Page</span></h1>
#
# <h1><span class="mw-headline" id="Welcome_to_Wikipedia">Welcome to <a href="/wiki/Wikipedia" title="Wikipedia">Wikipedia</a></span></h1>
#
# <h2 class="mp-h2" id="mp-tfa-h2"><span id="From_today.27s_featured_article"></span><span class="mw-headline" id="From_today's_featured_article">From today's featured article</span></h2>
#
# <h2 class="mp-h2" id="mp-dyk-h2"><span class="mw-headline" id="Did_you_know_...">Did you know ...</span></h2>
#
# <h2 class="mp-h2" id="mp-itn-h2"><span class="mw-headline" id="In_the_news">In the news</span></h2>
#
# <h2 class="mp-h2" id="mp-otd-h2"><span class="mw-headline" id="On_this_day">On this day</span></h2>
#
# ...

# %% [markdown]
# # Question 2 -IMDB top 100 Movies

# %%
p1=requests.get("https://www.imdb.com/search/title/?count=100&groups=top_1000&sort=user_rating")
p1
# Out:
# <Response [200]>

# %%
bs=BeautifulSoup(p1.content)

# %%
movie_name=[]

# %%
movie_data=bs.findAll('div',class_='lister-item mode-advanced')

# %%
# Scraping out 100 world wide movie name
for i in movie_data:
    name = i.h3.a.text
    movie_name.append(name)

# %%
import pandas as pd
import numpy as n

# %%
# Scraping out movie release year
year=[]

release_year=bs.findAll('span',class_='lister-item-year text-muted unbold')

for i in release_year:
    year.append(i.text.replace('(','').replace(')',''))

# %%
# Scraping out Rating of the movie
Rating=[]

rating_movie=bs.findAll('div',class_='inline-block ratings-imdb-rating')

for i in rating_movie:
    Rating.append(i.text.replace('\n\n','').replace('\n',''))

# %%
# Creating a table by using Pandas Data Frame 
movie_df=pd.DataFrame({'Name of Movie':movie_name,'Release Year':year,'Movie rating':Rating})

# %%
movie_df
# Out:
#                                     Name of Movie Release Year Movie rating
# 0                        The Shawshank Redemption         1994          9.3
# 1                                   The Godfather         1972          9.2
# 2                                 The Dark Knight         2008          9.0
# 3   The Lord of the Rings: The Return of the King         2003          9.0
# 4                                Schindler's List         1993          9.0
# ..                                            ...          ...          ...
# 95                    Witness for the Prosecution         1957          8.4
# 96                                 Paths of Glory         1957          8.4
# 97                                   Sunset Blvd.         1950          8.4
# 98                             The Great Dictator         1940          8.4
# 99                                     Chhichhore         2019          8.3
#
# [100 rows x 3 columns]

# %% [markdown]
# # Question 3- IMDB top 100 Bollywood Movies

# %%
ps=requests.get('https://www.imdb.com/list/ls009997493/')
ps
# Out:
# <Response [200]>

# %%
Bs=BeautifulSoup(ps.content)

# %%
# Scrapping out Bollywood Movie Names
Movie=[]
Mo_name=Bs.findAll('h3',class_='lister-item-header')

for i in Mo_name:
    Movie.append(i.a.text.replace('\n\n','').replace('\n',''))

# %%
# Scrapping out the release year of the movie
Year=[]

rel_year=Bs.findAll('span',class_='lister-item-year text-muted unbold')

for i in rel_year:
    Year.append(i.text.replace('(','').replace(')',''))

# %%
#Scrapping out the Rating of the movies
rating=[]

Rat_movie=Bs.findAll('div',class_='ipl-rating-star small')

for i in Rat_movie:
    rating.append(i.text.replace('\n\n','').replace('\n',''))

# %%
# Created table of top 100 bollywood movies on IMDB
Boll_mov=pd.DataFrame({'Movie':Movie,'release year':Year,'rating':rating})
Boll_mov
# Out:
#                      Movie release year rating
# 0          Rang De Basanti         2006    8.1
# 1                 3 Idiots         2009    8.4
# 2         Taare Zameen Par         2007    8.4
# 3           Dil Chahta Hai         2001    8.1
# 4   Swades: We, the People         2004    8.2
# ..                     ...          ...    ...
# 95             Wake Up Sid         2009    7.6
# 96                Rangeela         1995    7.4
# 97     Shatranj Ke Khilari         1977    7.5
# 98      Pyaar Ka Punchnama         2011    7.6
# 99           Ek Hasina Thi         2004    7.5
#
# [100 rows x 3 columns]

# %% [markdown]
# # Question 4 - List of Indian Presidents

# %%
a=requests.get('https://presidentofindia.nic.in/former-presidents.htm')
a
# Out:
# <Response [200]>

# %%
b=BeautifulSoup(a.content)

# %%
# Scrapping out Indian Presidents Name
Name_president=[]



for i in b.find_all("div",class_="presidentListing"):
    Name_president.append(i.find("h3").text.split('(')[0])

# %%
# Scrapping out the Office terms of the presidents 
Term =[]

office_term=b.find_all("div",class_="presidentListing")

for i in office_term:
    Term.append(i.find('p').text.replace('Term of Office:',''))

# %%
# Creating table for Indian President data 
Indian_president=pd.DataFrame({'Name of President':Name_president,'Term of Office':Term})
Indian_president
# Out:
#                 Name of President  \
# 0           Shri Ram Nath Kovind
# 1          Shri Pranab Mukherjee
# 2   Smt Pratibha Devisingh Patil
# 3         DR. A.P.J. Abdul Kalam
# 4           Shri K. R. Narayanan
# 5        Dr Shankar Dayal Sharma
# 6            Shri R Venkataraman
# 7               Giani Zail Singh
# 8      Shri Neelam Sanjiva Reddy
# 9       Dr. Fakhruddin Ali Ahmed
# 10  Shri Varahagiri Venkata Giri
# 11              Dr. Zakir Husain
# 12  Dr. Sarvepalli Radhakrishnan
# 13           Dr. Rajendra Prasad
#
#                                        Term of Office
# 0                     25 July, 2017 to 25 July, 2022
# 1                     25 July, 2012 to 25 July, 2017
# 2                     25 July, 2007 to 25 July, 2012
# 3                     25 July, 2002 to 25 July, 2007
# 4                     25 July, 1997 to 25 July, 2002
# 5                     25 July, 1992 to 25 July, 1997
# 6                     25 July, 1987 to 25 July, 1992
# ...

# %% [markdown]
# # Question 5- ICC Cricket Men's Detail

# %% [markdown]
# # Top 10 ODI Teams

# %%
page2=requests.get('https://www.icc-cricket.com/rankings/mens/team-rankings/t20i')
page2
# Out:
# <Response [200]>

# %%
soup2=BeautifulSoup(page2.content)

# %%
# Name of Top 10 teams in ICC Cricket Ranking 
Teams=[]

for i in soup2.find_all('span',class_='u-hide-phablet'):
    Teams.append(i.text)
    
T1=Teams[0:10]

# %%
# Creating the matches played list by each team
Matches=[]
for i in soup2.find_all('td',class_='table-body__cell u-center-text'):
    Matches.append(i.text)
    

Matches2=[]
for i in soup2.find_all('td',class_='rankings-block__banner--matches'):
    Matches2.append(i.text)

l1=Matches[0:166:2]

l2=Matches2[:]
l2

a=l1
b=l2
c=(b+a)

C1=c[0:10]

# %%
# Creating the overall points obtain by each team 
Point1=[]
for i in soup2.find_all('td',class_='rankings-block__banner--points'):
    Point1.append(i.text)
Point1

Point2=[]
for i in soup2.find_all('td',class_='table-body__cell u-center-text'):
    Point2.append(i.text)
Point2

a1=Point2[1::2]
a1

a2=Point1[:]
a2

b1=a1
b2=a2
c2=(b2+b1)

C2=c2[0:10]

# %%
#Creating a rating list of ecah team 
Rat1=[]
for i in soup2.find_all('td',class_='rankings-block__banner--rating'):
    Rat1.append(i.text.replace('\n','').replace('\n\n','').replace('  ',''))

    
Rat2=[]
for i in soup2.find_all('td',class_='table-body__cell u-text-right rating'):
    Rat2.append(i.text)


R1=Rat1
R2=Rat2

c3=(R1+R2)

C3=c3[0:10]

# %%
ICC_Teams=pd.DataFrame({'Teams':T1,'Matches':C1,'Points':C2,'Ratings':C3})
ICC_Teams
# Out:
#           Teams Matches  Points Ratings
# 0         India      63  16,881     268
# 1       England      49  13,029     266
# 2      Pakistan      55  14,168     258
# 3  South Africa      41  10,510     256
# 4   New Zealand      50  12,621     252
# 5     Australia      47  11,784     251
# 6   West Indies      51  12,039     236
# 7     Sri Lanka      50  11,732     235
# 8    Bangladesh      51  11,328     222
# 9   Afghanistan      30   6,512     217

# %% [markdown]
# # Top 10 ODI Batsman

# %%
page3=requests.get('https://www.icc-cricket.com/rankings/mens/player-rankings/odi/batting')
page3
# Out:
# <Response [200]>

# %%
soup3=BeautifulSoup(page3.content)

# %%
# Creating list for to 10 batsman name of ICC cricket ranking
P1=[]
for i in soup3.find_all('div',class_='rankings-block__banner--name-large'):
    P1.append(i.text)
    

P2=[]
for i in soup3.find_all('td',class_='table-body__cell rankings-table__name name'):
    P2.append(i.text.replace('\n',''))
    
player=(P1+P2)

P3=player[0:10]

# %%
# Creating list of the team from which the batsman belongs 
T1=[]
for i in soup3.find_all('div',class_='rankings-block__banner--nationality'):
    T1.append(i.text.replace('\n\n','').replace('\n','').replace('  ',''))
    
T2=[]
for i in soup3.find_all('td',class_='table-body__cell nationality-logo rankings-table__team'):
    T2.append(i.text.replace('\n\n','').replace('\n',''))
    
Teams=(T1+T2)
T3=Teams[0:10]

# %%
# Creating list of the rating of the batsman
R1=[]
for i in soup3.find_all('div',class_='rankings-block__banner--rating'):
    R1.append(i.text)
    
    
R2=[]
for i in soup3.find_all('td',class_='table-body__cell rating'):
    R2.append(i.text)
    
Rate=(R1+R2)

R3=Rate[0:10]

# %%
ODI_Batsman=pd.DataFrame({'Name of Player':P3,'Teams':T3,'Rating':R3})
ODI_Batsman
# Out:
#           Name of Player Teams Rating
# 0             Babar Azam   PAK    890
# 1            Imam-ul-Haq   PAK    779
# 2  Rassie van der Dussen    SA    766
# 3        Quinton de Kock    SA    759
# 4           David Warner   AUS    747
# 5            Steve Smith   AUS    719
# 6         Jonny Bairstow   ENG    710
# 7            Virat Kohli   IND    707
# 8           Rohit Sharma   IND    704
# 9        Kane Williamson    NZ    701

# %% [markdown]
# # Top 10 ODI Bowlers

# %%
page4=requests.get('https://www.icc-cricket.com/rankings/mens/player-rankings/odi/bowling')
page4
# Out:
# <Response [200]>

# %%
soup4=BeautifulSoup(page4.content)

# %%
# Creating list of top 10 bowlers name 
N1=[]
for i in soup4.find_all('div',class_='rankings-block__banner--name-large'):
    N1.append(i.text)
    
N2=[]
for i in soup4.find_all('td',class_='table-body__cell rankings-table__name name'):
    N2.append(i.text.replace('\n',''))
    
N=(N1+N2)
bowler=N[0:10]

# %%
# creating list of team of the bowlers 
p1=[]
for i in soup4.find_all('div',class_='rankings-block__banner--nationality'):
    p1.append(i.text.replace('\n\n','').replace('\n','').replace('  ',''))

p2=[]
for i in soup4.find_all('td',class_='table-body__cell nationality-logo rankings-table__team'):
    p2.append(i.text.replace('\n\n','').replace('\n',''))

play=(p1+p2)
bow_team=play[0:10]

# %%
# Creating list of Bowlers rating point 
r1=[]
for i in soup4.find_all('div',class_='rankings-block__banner--rating'):
    r1.append(i.text)
    
r2=[]
for i in soup4.find_all('td',class_='table-body__cell rating'):
    r2.append(i.text)
r3=(r1+r2)
bow_rate=r3[0:10]

# %%
ODI_bowler=pd.DataFrame({'Name of Bowler':bowler,'Teams':bow_team,'Rating':bow_rate})
ODI_bowler
# Out:
#       Name of Bowler Teams Rating
# 0        Trent Boult    NZ    760
# 1     Josh Hazlewood   AUS    727
# 2     Mitchell Starc   AUS    665
# 3     Shaheen Afridi   PAK    661
# 4         Matt Henry    NZ    656
# 5         Adam Zampa   AUS    655
# 6       Mehedi Hasan   BAN    655
# 7   Mujeeb Ur Rahman   AFG    650
# 8  Mustafizur Rahman   BAN    640
# 9        Rashid Khan   AFG    635

# %% [markdown]
# # Question -6 ICC Cricket  women

# %% [markdown]
# # ODI Team Ranking

# %%
page5=requests.get('https://www.icc-cricket.com/rankings/womens/team-rankings/odi')
page5
# Out:
# <Response [200]>

# %%
soup5=BeautifulSoup(page5.content)

# %%
# Creating list of top 10 ICC womens cricket team 
Team=[]
for i in soup5.find_all('span',class_='u-hide-phablet'):
    Team.append(i.text)
T1=Team[0:10]

# %%
# Creating list of matches of each team
matches1=[]
for i in soup5.find_all('td',class_='rankings-block__banner--matches'):
    matches1.append(i.text)

matches2=[]
for i in soup5.find_all('td',class_='table-body__cell u-center-text'):
    matches2.append(i.text)
m1=matches2[0::2]
m1
Matchs=(matches1+m1)
M=Matchs[0:10]

# %%
# Creating list for points of the team 
p1=[]
for i in soup5.find_all('td',class_='rankings-block__banner--points'):
    p1.append(i.text)
p2=[]
for i in soup5.find_all('td',class_='table-body__cell u-center-text'):
    p2.append(i.text)
p3=p2[1::2]
points=(p1+p3)
P=points[0:10]

# %%
# Creating the list of team rating 
R1=[]
for i in soup5.find_all('td',class_='rankings-block__banner--rating u-text-right'):
    R1.append(i.text.replace('\n','').replace('\n\n','').replace('  ',''))
R2=[]
for i in soup5.find_all('td',class_='table-body__cell u-text-right rating'):
    R2.append(i.text)
Rate=(R1+R2)
R=Rate[0:10]

# %%
Women_cricket=pd.DataFrame({'Teams':T1,'Matches':M,'Points':P,'Rating':R})
Women_cricket
# Out:
#           Teams Matches Points Rating
# 0     Australia      18  3,061    170
# 1  South Africa      26  3,098    119
# 2       England      25  2,904    116
# 3         India      27  2,820    104
# 4   New Zealand      24  2,425    101
# 5   West Indies      24  2,334     97
# 6    Bangladesh      12    932     78
# 7      Thailand       8    572     72
# 8      Pakistan      24  1,519     63
# 9     Sri Lanka       8    353     44

# %% [markdown]
# # Women Cricket ODI Batting Ranking

# %%
page6=requests.get('https://www.icc-cricket.com/rankings/womens/player-rankings/odi/batting')
page6
# Out:
# <Response [200]>

# %%
soup6=BeautifulSoup(page6.content)

# %%
# Creating list of Women batting 
n1=[]
for i in soup6.find_all('div',class_='rankings-block__banner--name-large'):
    n1.append(i.text)
n2=[]
for i in soup6.find_all('td',class_='table-body__cell rankings-table__name name'):
    n2.append(i.text.replace('\n',''))
n3=(n1+n2)
Name=n3[0:10]

# %%
# Creating list of team from which the women batter belongs 
t1=[]
for i in soup6.find_all('div',class_='rankings-block__banner--nationality'):
    t1.append(i.text.replace('\n\n','').replace('\n','').replace('  ',''))
    
t2=[]
for i in soup6.find_all('td',class_='table-body__cell nationality-logo rankings-table__team'):
    t2.append(i.text.replace('\n\n','').replace('\n',''))
t3=(t1+t2)
team=t3[0:10]

# %%
# Create the list of Batters rating 
r1=[]
for i in soup6.find_all('div',class_='rankings-block__banner--rating'):
    r1.append(i.text)
r2=[]
for i in soup6.find_all('td',class_='table-body__cell rating'):
    r2.append(i.text)
r3=(r1+r2)
Ratein=r3[0:10]

# %%
Women_batting=pd.DataFrame({'player Name':Name,'Team':team,'Rateing':Ratein})
Women_batting
# Out:
#            player Name Team Rateing
# 0         Alyssa Healy  AUS     785
# 1          Beth Mooney  AUS     749
# 2      Laura Wolvaardt   SA     732
# 3       Natalie Sciver  ENG     725
# 4     Harmanpreet Kaur  IND     716
# 5      Smriti Mandhana  IND     714
# 6          Meg Lanning  AUS     710
# 7       Rachael Haynes  AUS     701
# 8    Amy Satterthwaite   NZ     661
# 9  Chamari Athapaththu   SL     655

# %% [markdown]
# # Women All-rounder

# %%
page11=requests.get('https://www.icc-cricket.com/rankings/womens/player-rankings/odi/all-rounder')
page11
# Out:
# <Response [200]>

# %%
soup11=BeautifulSoup(page11.content)

# %%
# List of women cricketr all rounders
player1=[]
for i in soup11.find_all('div',class_='rankings-block__banner--name-large'):
    player1.append(i.text)
player2=[]
for i in soup11.find_all('td',class_='table-body__cell rankings-table__name name'):
    player2.append(i.text.replace('\n',''))
p=(player1+player2)
Player=p[0:10]

# %%
# Creating the list of Team of all rounders
Te1=[]
for i in soup11.find_all('div',class_='rankings-block__banner--nationality'):
    Te1.append(i.text.replace('\n\n','').replace('\n','').replace('  ',''))
Te2=[]
for i in soup11.find_all('td',class_='table-body__cell nationality-logo rankings-table__team'):
    Te2.append(i.text.replace('\n\n','').replace('\n','').replace('  ',''))
Te=(Te1+Te2)
Team=Te[0:10]

# %%
# Creating the Rating list of all rounders 
Re1=[]
for i in soup11.find_all('div',class_='rankings-block__banner--rating'):
    Re1.append(i.text)
Re2=[]
for i in soup11.find_all('td',class_='table-body__cell rating'):
    Re2.append(i.text)
Re=(Re1+Re2)
rate=Re[0:10]

# %%
Women_Allrounder=pd.DataFrame({'Player Name':Player,'Team':Team,'Rateing':rate})
Women_Allrounder
# Out:
#         Player Name Team Rateing
# 0   Hayley Matthews   WI     380
# 1      Ellyse Perry  AUS     374
# 2    Natalie Sciver  ENG     357
# 3       Amelia Kerr   NZ     356
# 4    Marizanne Kapp   SA     349
# 5     Deepti Sharma  IND     322
# 6  Ashleigh Gardner  AUS     270
# 7     Jess Jonassen  AUS     246
# 8    Jhulan Goswami  IND     214
# 9   Katherine Brunt  ENG     207

# %% [markdown]
# # Question 7 - Scraping News Details

# %%
from bs4 import BeautifulSoup,SoupStrainer

import requests

import pandas as pd

# %%
News_soup=BeautifulSoup(requests.get("https://www.cnbc.com/world/?region=world").content,"html.parser")

 # Scrap Headlines

# %%
# Creating the list of head lines
Headline=[i.text for i in News_soup.find_all(class_="LatestNews-headline")]

# %%
# Creating the Time list of the news relese
time=[i.text for i in News_soup.find_all(class_="LatestNews-timestamp")]

# %%
# Creating the news link url list 
news_link=[i.get('href')for i in News_soup.find_all(class_="LatestNews-headline")]

# %%
cnbc_news=pd.DataFrame({'Headline':Headline,'Time':time,'News_link':news_link})
cnbc_news
# Out:
#                                              Headline          Time  \
# 0   Cramer's lightning round: Let Extreme Networks...  10 Hours Ago
# 1   Jim Cramer says these 3 apparel stocks benefit...  10 Hours Ago
# 2   Cramer’s week ahead: Markets need a strong job...  11 Hours Ago
# 3   Pro Picks: Watch all of Friday's big stock cal...  12 Hours Ago
# 4   There is 'enormous opportunity' in REITs, says...  12 Hours Ago
# 5   Biden administration will end monkeypox public...  13 Hours Ago
# 6   Expect more choppiness ahead after a week of m...  13 Hours Ago
# 7   GM, LG investing $275 million to expand Tennes...  14 Hours Ago
# 8   These beat-up tech stocks have potential, ‘Hal...  14 Hours Ago
# 9   The Fed's path to a 'Goldilocks' economy just ...  14 Hours Ago
# 10  3 things crypto investors need to know in post...  14 Hours Ago
# 11  Biden condemns antisemitism as Ye praises Hitl...  14 Hours Ago
# 12  Georgia man arrested for shooting boy campaign...  14 Hours Ago
# ...

# %% [markdown]
# # Question 8 - AI Articals

# %%
page8=requests.get('https://www.journals.elsevier.com/artificial-intelligence/most-downloaded-articles')
page8
# Out:
# <Response [200]>

# %%
soup8=BeautifulSoup(page8.content)

# %%
# Creating the paper list 
paper_title=[]
for i in soup8.find_all('h2',class_='sc-1qrq3sd-1 gRGSUS sc-1nmom32-0 sc-1nmom32-1 btcbYu goSKRg'):
    paper_title.append(i.text)

# %%
# Creating the list of author
Author=[]
for i in soup8.find_all('span',class_='sc-1w3fpd7-0 dnCnAO'):
    Author.append(i.text)

# %%
# creating the list of article publish date
publish_date=[]
for i in soup8.find_all('span',class_='sc-1thf9ly-2 dvggWt'):
    publish_date.append(i.text)

# %%
# Creating the list of url 
paper_URL=[]
for i in soup8.find_all('a',class_='sc-5smygv-0 fIXTHm'):
    paper_URL.append(i.get('href')) # getting url

# %%
AI_Articales=pd.DataFrame({'Paper Title':paper_title,'Authors':Author,'Publish Date':publish_date,'URL':paper_URL})
AI_Articales
# Out:
#                                           Paper Title  \
# 0                                    Reward is enough
# 1                           Making sense of raw input
# 2   Law and logic: A review from an argumentation ...
# 3              Creativity and artificial intelligence
# 4   Artificial cognition for social human–robot in...
# 5   Explanation in artificial intelligence: Insigh...
# 6                       Making sense of sensory input
# 7   Conflict-based search for optimal multi-agent ...
# 8   Between MDPs and semi-MDPs: A framework for te...
# 9   The Hanabi challenge: A new frontier for AI re...
# 10  Evaluating XAI: A comparison of rule-based and...
# 11           Argumentation in artificial intelligence
# 12  Algorithms for computing strategies in two-pla...
# 13      Multiple object tracking: A literature review
# 14  Selection of relevant features and examples in...
# 15  A survey of inverse reinforcement learning: Ch...
# ...

# %% [markdown]
# # Question-9 - Dineout

# %%
page7=requests.get('https://www.dineout.co.in/delhi-restaurants/buffet-special')
page7
# Out:
# <Response [200]>

# %%
soup7=BeautifulSoup(page7.content)

# %%
# Creating the list of hotel name
title=[]
for i in soup7.find_all('a',class_='restnt-name ellipsis'):
    title.append(i.text)

# %%
# Creating the list of hotel place
place=[]
for i in soup7.find_all('div',class_='restnt-loc ellipsis'):
    place.append(i.text)

# %%
# Creating the list of hotel price
price=[]
for i in soup7.find_all('span',class_='double-line-ellipsis'):
    price.append(i.text.split('|')[0])

# %%
# Creating the list of hotel cusin
Cusin=[]
for i in soup7.find_all('span',class_='double-line-ellipsis'):
    Cusin.append(i.text.split('|')[1])

# %%
# Creating the list of hotel rateing 
Rating=[]
for i in soup7.find_all('div',class_='restnt-rating rating-4'):
    Rating.append(i.text)

# %%
image=[]
for i in soup7.find_all('img',class_='no-img'):
    image.append(i.get('data-src'))  # scraping the url

# %%
Hotel_detail=pd.DataFrame({'Name':title,'Location':place,'Price':price,'Cusin':Cusin,'Rating':Rating,'URL':image})
Hotel_detail
# Out:
#                                Name  \
# 0                   Castle Barbeque
# 1                   Jungle Jamboree
# 2                   Castle Barbeque
# 3                        Cafe Knosh
# 4              The Barbeque Company
# 5                       India Grill
# 6                    Delhi Barbeque
# 7  The Monarch - Bar Be Que Village
# 8                 Indian Grill Room
#
#                                             Location                    Price  \
# 0                     Connaught Place, Central Delhi  ₹ 2,000 for 2 (approx)
# 1             3CS Mall,Lajpat Nagar - 3, South Delhi  ₹ 1,680 for 2 (approx)
# 2             Pacific Mall,Tagore Garden, West Delhi  ₹ 2,000 for 2 (approx)
# 3  The Leela Ambience Convention Hotel,Shahdara, ...  ₹ 3,000 for 2 (approx)
# 4                 Gardens Galleria,Sector 38A, Noida  ₹ 1,700 for 2 (approx)
# 5               Hilton Garden Inn,Saket, South Delhi  ₹ 2,400 for 2 (approx)
# ...

# %% [markdown]
# # Question 10- Top Publications

# %%
page10=requests.get('https://scholar.google.com/citations?view_op=top_venues&hl=en')
page10
# Out:
# <Response [200]>

# %%
soup10=BeautifulSoup(page10.content)

# %%
# Create list of ranking 
Rank=[]
for i in soup10.find_all('td',class_='gsc_mvt_p'):
    Rank.append(i.text)

# %%
# Create list of Publication name
publication=[]
for i in soup10.find_all('td',class_='gsc_mvt_t'):
    publication.append(i.text)

# %%
#Create list of h5-index
index=[]
for i in soup10.find_all('td',class_='gsc_mvt_n'):
    index.append(i.text)
h5=index[0:200:2]

# %%
# Creating list of h5-median
median=[]
for i in soup10.find_all('span',class_='gs_ibl gsc_mp_anchor'):
    median.append(i.text)

# %%
Google_scholar=pd.DataFrame({'Rank':Rank,'Publications':publication,'h5 index':h5,'h5 median':median})
Google_scholar
# Out:
#     Rank                                       Publications h5 index h5 median
# 0     1.                                             Nature      444       667
# 1     2.                The New England Journal of Medicine      432       780
# 2     3.                                            Science      401       614
# 3     4.  IEEE/CVF Conference on Computer Vision and Pat...      389       627
# 4     5.                                         The Lancet      354       635
# ..   ...                                                ...      ...       ...
# 95   96.                       Journal of Business Research      145       233
# 96   97.                                   Molecular Cancer      145       209
# 97   98.                                            Sensors      145       201
# 98   99.                              Nature Climate Change      144       228
# 99  100.                    IEEE Internet of Things Journal      144       212
#
# [100 rows x 4 columns]
